# %%
from sage.misc.html import latex
# %display latex

# %%
var("theta")
# Out:
# theta

# %%
var("R")
x = R * exp(i * theta)

# %%
var("s")
var("a", "b")
# Out:
# (a, b)

# %%
exp(s * x - s^3 / 3)
# Out:
# e^(-1/3*s^3 + R*s*e^(I*theta))

# %%
contour_plot(lambda k, l: real(s * x - s^3 / 3).substitute(R = 50, theta=0).substitute(s = k + l*i), (-4, 4), (-4, 4), contours=25)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
contour_plot(lambda k, l: real(s * x - s^3 / 3).substitute(R = 1, theta=0).substitute(s = k + l*i), (-4, 4), (-4, 4), contours=25)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
# the first issue is that the saddle points move as x changes. Need to change variables

# %%
contour_plot(lambda k, l: real(s * x - s^3 / 3).substitute(R = 1, theta=pi / 2).substitute(s = k + l*i), (-4, 4), (-4, 4), contours=25)
# Out:
# Graphics object consisting of 1 graphics primitive
